# %%
import pandas as pd

print("Day 4: Pandas Started 📊")

# CSV file load karo
df = pd.read_csv('student_scores.csv')

# Pehle 5 rows dekho
print("\nFirst 5 rows:")
print(df.head())

# Dataset ki info
print("\nDataset Info:")
print(df.info())

# Shape aur Columns
print("\nShape:", df.shape)
print("Columns:", df.columns.tolist())

# Basic Statistics
print("\nStatistics:")
print(df.describe())
