# %%
print("Day 1: Environment setup complete! 🚀")
print("Ready to start my AI & ML Internship at Codomax Digital Solutions")
name = "Nazmeen"
day = 1
print(f"Hello, I am {name} starting Day {day} of the internship.")
# Out:
# Day 1: Environment setup complete! 🚀
# Ready to start my AI & ML Internship at Codomax Digital Solutions
# Hello, I am Nazmeen starting Day 1 of the internship.
